# %%
import matplotlib.pyplot as plt

class Livro:
    def __init__(self, titulo, autor, genero, quantidade_disponivel):
        self.titulo = titulo
        self.autor = autor
        self.genero = genero
        self.quantidade_disponivel = quantidade_disponivel

livros = []

def cadastrar_livro(titulo, autor, genero, quantidade):
    livro = Livro(titulo, autor, genero, quantidade)
    livros.append(livro)
    print(f"Livro '{titulo}' cadastrado com sucesso!")

def listar_livros():
    if not livros:
        print("Nenhum livro cadastrado ainda.")
    else:
        for livro in livros:
            print(f"Título: {livro.titulo}, Autor: {livro.autor}, Gênero: {livro.genero}, Quantidade disponível: {livro.quantidade_disponivel}")

def buscar_livro_por_titulo(titulo):
    for livro in livros:
        if livro.titulo.lower() == titulo.lower():
            print(f"Título: {livro.titulo}, Autor: {livro.autor}, Gênero: {livro.genero}, Quantidade disponível: {livro.quantidade_disponivel}")
            return
    print(f"Livro com o título '{titulo}' não encontrado.")

def gerar_grafico_livros_por_genero():
    generos = {}
    for livro in livros:
        if livro.genero in generos:
            generos[livro.genero] += livro.quantidade_disponivel
        else:
            generos[livro.genero] = livro.quantidade_disponivel

    plt.bar(generos.keys(), generos.values())
    plt.xlabel("Gênero")
    plt.ylabel("Quantidade de Livros")
    plt.title("Quantidade de Livros por Gênero")
    plt.show()

# Exemplo de uso:
cadastrar_livro("Dom Quixote", "Miguel de Cervantes", "Aventura", 5)
cadastrar_livro("O Pequeno Príncipe", "Antoine de Saint-Exupéry", "Infantil", 3)
cadastrar_livro("1984", "George Orwell", "Ficção Científica", 2)
cadastrar_livro("A Revolução dos Bichos", "George Orwell", "Ficção Científica", 4)

listar_livros()

buscar_livro_por_titulo("1984")
buscar_livro_por_titulo("Harry Potter")

gerar_grafico_livros_por_genero()
# Out:
# Livro 'Dom Quixote' cadastrado com sucesso!
# Livro 'O Pequeno Príncipe' cadastrado com sucesso!
# Livro '1984' cadastrado com sucesso!
# Livro 'A Revolução dos Bichos' cadastrado com sucesso!
# Título: Dom Quixote, Autor: Miguel de Cervantes, Gênero: Aventura, Quantidade disponível: 5
# Título: O Pequeno Príncipe, Autor: Antoine de Saint-Exupéry, Gênero: Infantil, Quantidade disponível: 3
# Título: 1984, Autor: George Orwell, Gênero: Ficção Científica, Quantidade disponível: 2
# Título: A Revolução dos Bichos, Autor: George Orwell, Gênero: Ficção Científica, Quantidade disponível: 4
# Título: 1984, Autor: George Orwell, Gênero: Ficção Científica, Quantidade disponível: 2
# Livro com o título 'Harry Potter' não encontrado.
